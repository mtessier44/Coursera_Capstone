# %%
#In this notebook we will get the data we need to accomplish the project

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 6.3 MB/s eta 0:00:011
# Collecting branca
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=e02c3552c435d8e018be90852915782aae7eebf86b0c2261f1f39feec5f68935
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.5.0
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'OUSZRIXO1TXAFQDSPRIUUKBDKROIKAM3RBOLEJU5MAQAUKZI' # your Foursquare ID
CLIENT_SECRET = 'Z5BH0GXTGSL35LVSWOGFC3OKLQGDPW5L2I05HED3TEQBAGHR' # your Foursquare Secret
ACCESS_TOKEN = 'S3Y4QAX2FZAOBEK3GLVVQ20QTQPZD2OPMZ45SJ5WTYCQPLW5' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: OUSZRIXO1TXAFQDSPRIUUKBDKROIKAM3RBOLEJU5MAQAUKZI
# CLIENT_SECRET:Z5BH0GXTGSL35LVSWOGFC3OKLQGDPW5L2I05HED3TEQBAGHR

# %%
address = 'Quai des orfèvres, Paris, France' #This place is considered as the center of Paris

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 48.8548227 2.34378

# %%
search_query = 'Pizzeria' #We will look for pizzeria in a radius of 5 km from the center
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Pizzeria .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=OUSZRIXO1TXAFQDSPRIUUKBDKROIKAM3RBOLEJU5MAQAUKZI&client_secret=Z5BH0GXTGSL35LVSWOGFC3OKLQGDPW5L2I05HED3TEQBAGHR&ll=48.8548227,2.34378&oauth_token=S3Y4QAX2FZAOBEK3GLVVQ20QTQPZD2OPMZ45SJ5WTYCQPLW5&v=20180604&query=Pizzeria&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60127acfe305641b09f01ca9'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '51430960e4b0455b2d070f45',
#     'name': 'Pizzeria Italiana Da Michele',
#     'location': {'address': '57 rue Notre Dame de Nazareth',
#      'lat': 48.867739,
#      'lng': 2.356261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867739,
#        'lng': 2.356261}],
#      'distance': 1703,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['57 rue Notre Dame de Nazareth', '75013 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4c9894df07916dcb8d01ed1b',
#     'name': "O'scià Pizzeria Napoletana",
#     'location': {'address': '42 rue Tiquetonne',
#      'crossStreet': 'Rue Montorgueil',
#      'lat': 48.86482080982636,
#      'lng': 2.3475238898838597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86482080982636,
#        'lng': 2.3475238898838597}],
#      'distance': 1146,
#      'postalCode': '75002',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['42 rue Tiquetonne (Rue Montorgueil)',
#       '75002 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '145488698'},
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4dc445371f6ef43b89f7e46e',
#     'name': "Pizzeria d'Istanbul",
#     'location': {'address': "101 boulevard de l'Hôpital",
#      'lat': 48.837677,
#      'lng': 2.359962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.837677,
#        'lng': 2.359962}],
#      'distance': 2246,
#      'postalCode': '75013',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["101 boulevard de l'Hôpital", '75013 Paris']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4c6fb714d274b60c3d57d70d',
#     'name': 'Pizzeria Mazarine',
#     'location': {'address': '41 rue Mazarine',
#      'lat': 48.853989,
#      'lng': 2.337987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.853989,
#        'lng': 2.337987}],
#      'distance': 434,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['41 rue Mazarine', '75005 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '5371073c498e8b0d316a4db8',
#     'name': 'Pizzeria Maccaron',
#     'location': {'address': '22 rue des Bourdonnais',
#      'lat': 48.85945352057837,
#      'lng': 2.3444008827209473,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85945352057837,
#        'lng': 2.3444008827209473}],
#      'distance': 517,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['22 rue des Bourdonnais', '75001 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '5131ded7e4b04a7c69396261',
#     'name': 'Pizzeria Pepone',
#     'location': {'address': '3 rue Grégoire de Tours',
#      'lat': 48.85351139737257,
#      'lng': 2.3379674161065784,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85351139737257,
#        'lng': 2.3379674161065784}],
#      'distance': 450,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['3 rue Grégoire de Tours', '75006 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '523741de11d2a8888a604602',
#     'name': 'Pizzeria Nino',
#     'location': {'address': "8 rue d'Alleray",
#      'lat': 48.839535,
#      'lng': 2.299931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.839535,
#        'lng': 2.299931}],
#      'distance': 3635,
#      'postalCode': '75015',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["8 rue d'Alleray", '75015 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4e59e059483b865169e59dba',
#     'name': 'Pizzeria La Gaine',
#     'location': {'lat': 48.859215,
#      'lng': 2.354996,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.859215,
#        'lng': 2.354996}],
#      'distance': 955,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '573eecb1498ebf4b4efd1b8c',
#     'name': 'Pizzeria Luciana',
#     'location': {'address': '187 rue Saint-Jacques',
#      'lat': 48.845296617961125,
#      'lng': 2.3426158726215363,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.845296617961125,
#        'lng': 2.3426158726215363}],
#      'distance': 1063,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['187 rue Saint-Jacques', '75005 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4e59fe822271886714fb58d5',
#     'name': 'Pizzeria Luka',
#     'location': {'lat': 48.862086730887796,
#      'lng': 2.351835696360754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.862086730887796,
#        'lng': 2.351835696360754}],
#      'distance': 1000,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4e58fd782271886714ec7f9d',
#     'name': 'Pizzeria Ghost',
#     'location': {'lat': 48.861029,
#      'lng': 2.358219,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.861029,
#        'lng': 2.358219}],
#      'distance': 1263,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '58ce831d18fd2b1c6a40c5ec',
#     'name': 'pizzeria',
#     'location': {'address': 'Rue Coustou',
#      'lat': 48.884677,
#      'lng': 2.333735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.884677,
#        'lng': 2.333735}],
#      'distance': 3403,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Rue Coustou', 'Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '513130f5e4b0ed2721b6e1fa',
#     'name': 'Mama Pizzeria',
#     'location': {'address': '109 rue de Bagnolet',
#      'crossStreet': 'Mama Shelter',
#      'lat': 48.85977818722424,
#      'lng': 2.4025445467138775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85977818722424,
#        'lng': 2.4025445467138775}],
#      'distance': 4339,
#      'postalCode': '75020',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['109 rue de Bagnolet (Mama Shelter)',
#       '75020 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '51043554e4b08881ebbec640',
#     'name': 'Pizzeria Romanella',
#     'location': {'address': '56 boulevard Saint-Marcel',
#      'lat': 48.83822250366211,
#      'lng': 2.356449604034424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.83822250366211,
#        'lng': 2.356449604034424}],
#      'distance': 2067,
#      'postalCode': '75005',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['56 boulevard Saint-Marcel', '75005 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '53f79936498ef939417afa78',
#     'name': 'Pizzeria Don Jacomo',
#     'location': {'lat': 48.853623153722694,
#      'lng': 2.3702556726468638,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.853623153722694,
#        'lng': 2.3702556726468638}],
#      'distance': 1943,
#      'cc': 'FR',
#      'country': 'France'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '5b5e12e160255e002c0d5d51',
#     'name': 'Pizzeria Sette',
#     'location': {'address': '31 rue de Sedaine',
#      'lat': 48.85655,
#      'lng': 2.373932,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85655,
#        'lng': 2.373932}],
#      'distance': 2216,
#      'postalCode': '75011',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['31 rue de Sedaine', '75011 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4ba66d6cf964a520635139e3',
#     'name': 'Pizzeria Les Comédiens',
#     'location': {'address': '44 boulevard du Montparnasse',
#      'lat': 48.844731,
#      'lng': 2.320639,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.844731,
#        'lng': 2.320639}],
#      'distance': 2033,
#      'postalCode': '75015',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['44 boulevard du Montparnasse', '75015 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '53f7b51b498e5ac6875be50a',
#     'name': 'Pizzeria Sette',
#     'location': {'address': '38 rue du Faubourg Saint Dénis',
#      'lat': 48.871269989113344,
#      'lng': 2.3534638646036896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.871269989113344,
#        'lng': 2.3534638646036896}],
#      'distance': 1963,
#      'cc': 'FR',
#      'country': 'France',
#      'formattedAddress': ['38 rue du Faubourg Saint Dénis']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '543eb095498e12bc703d80a5',
#     'name': 'Pizzeria Miramar',
#     'location': {'lat': 48.870489011559,
#      'lng': 2.320640403105704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.870489011559,
#        'lng': 2.320640403105704}],
#      'distance': 2431,
#      'cc': 'FR',
#      'country': 'France'},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4e972515b634527c67a6595a',
#     'name': 'Pizzeria Saint Georges',
#     'location': {'lat': 48.87722033627621,
#      'lng': 2.354398001782147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87722033627621,
#        'lng': 2.354398001782147}],
#      'distance': 2611,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4e0328be7d8bf11e9f3c1383',
#     'name': 'Pizzeria Napoletana',
#     'location': {'lat': 48.85339566986454,
#      'lng': 2.378798872232437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85339566986454,
#        'lng': 2.378798872232437}],
#      'distance': 2569,
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4b41e2a0f964a520c7c925e3',
#     'name': 'Pizzeria Saint-Lazare',
#     'location': {'address': '13 rue Saint-Lazare',
#      'lat': 48.876788,
#      'lng': 2.337441,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.876788,
#        'lng': 2.337441}],
#      'distance': 2488,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['13 rue Saint-Lazare', '75009 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4eef943377c82b92fa7121d1',
#     'name': 'Pizzeria Chez Hino',
#     'location': {'address': '56 Rue Falguière',
#      'lat': 48.840488227808734,
#      'lng': 2.3122441078179587,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.840488227808734,
#        'lng': 2.3122441078179587}],
#      'distance': 2807,
#      'postalCode': '75015',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['56 Rue Falguière', '75015 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4b8d6621f964a5206ff932e3',
#     'name': "Pizzeria d'Auteuil",
#     'location': {'address': '81 rue La Fontaine',
#      'lat': 48.8487727324926,
#      'lng': 2.2658393082903716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8487727324926,
#        'lng': 2.2658393082903716}],
#      'distance': 5748,
#      'postalCode': '75016',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['81 rue La Fontaine', '75016 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4d946494ca3f6ea8f502c834',
#     'name': 'Pizzeria Via Maria',
#     'location': {'address': '78-82 rue du Château',
#      'crossStreet': 'Place de Catalogne',
#      'lat': 48.83699738076995,
#      'lng': 2.318551957102554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.83699738076995,
#        'lng': 2.318551957102554}],
#      'distance': 2711,
#      'postalCode': '75014',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['78-82 rue du Château (Place de Catalogne)',
#       '75014 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4b8bffebf964a52082b732e3',
#     'name': 'Pizzeria Renato',
#     'location': {'address': '41 boulevard du Temple',
#      'lat': 48.86634787240057,
#      'lng': 2.364820606931472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86634787240057,
#        'lng': 2.364820606931472}],
#      'distance': 2005,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['41 boulevard du Temple', '75003 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4f91c6eae4b0ccf0717648df',
#     'name': 'Vecchia Bar Pizzeria',
#     'location': {'lat': 48.854704305840386,
#      'lng': 2.324866090926912,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.854704305840386,
#        'lng': 2.324866090926912}],
#      'distance': 1385,
#      'cc': 'FR',
#      'country': 'France'},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4b5f4f04f964a52038b329e3',
#     'name': 'Valponi Pizzeria',
#     'location': {'address': '9 boulevard Poissonnière',
#      'lat': 48.870939562104844,
#      'lng': 2.3465834151376166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.870939562104844,
#        'lng': 2.3465834151376166}],
#      'distance': 1805,
#      'postalCode': '75009',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['9 boulevard Poissonnière', '75009 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '5559c8ae498e23395fd9c60d',
#     'name': 'Pizzeria Al Taglio',
#     'location': {'address': '27 rue Erard',
#      'lat': 48.846176,
#      'lng': 2.38659,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.846176,
#        'lng': 2.38659}],
#      'distance': 3280,
#      'postalCode': '75012',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['27 rue Erard', '75012 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False},
#    {'id': '4f999df4e4b03d12fb0b163e',
#     'name': 'Pizzeria Verona',
#     'location': {'address': '11 bis rue de la Procession',
#      'lat': 48.83951950073242,
#      'lng': 2.3057215213775635,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.83951950073242,
#        'lng': 2.3057215213775635}],
#      'distance': 3267,
#      'postalCode': '75015',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['11 bis rue de la Procession', '75015 Paris']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1611823824',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                          name  \
# 0  51430960e4b0455b2d070f45  Pizzeria Italiana Da Michele
# 1  4c9894df07916dcb8d01ed1b    O'scià Pizzeria Napoletana
# 2  4dc445371f6ef43b89f7e46e           Pizzeria d'Istanbul
# 3  4c6fb714d274b60c3d57d70d             Pizzeria Mazarine
# 4  5371073c498e8b0d316a4db8             Pizzeria Maccaron
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1611823824    False
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1611823824    False
# 2  [{'id': '4f04af1f2fb6e1c99f3db0bb', 'name': 'T...  v-1611823824    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1611823824    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1611823824    False
#
#                 location.address  location.lat  location.lng  \
# 0  57 rue Notre Dame de Nazareth     48.867739      2.356261
# 1              42 rue Tiquetonne     48.864821      2.347524
# 2     101 boulevard de l'Hôpital     48.837677      2.359962
# 3                41 rue Mazarine     48.853989      2.337987
# 4         22 rue des Bourdonnais     48.859454      2.344401
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 48.867739, 'lng':...               1703
# 1  [{'label': 'display', 'lat': 48.86482080982636...               1146
# 2  [{'label': 'display', 'lat': 48.837677, 'lng':...               2246
# 3  [{'label': 'display', 'lat': 48.853989, 'lng':...                434
# 4  [{'label': 'display', 'lat': 48.85945352057837...                517
#
#   location.postalCode location.cc location.city location.state  \
# 0               75013          FR         Paris  Île-de-France
# 1               75002          FR         Paris  Île-de-France
# 2               75013          FR         Paris  Île-de-France
# 3               75005          FR         Paris  Île-de-France
# 4               75001          FR         Paris  Île-de-France
#
# 20                             NaN  48.853396  2.378799
# 21             13 rue Saint-Lazare  48.876788  2.337441
# 22                56 Rue Falguière  48.840488  2.312244
# 23              81 rue La Fontaine  48.848773  2.265839
# 24            78-82 rue du Château  48.836997  2.318552
# 25          41 boulevard du Temple  48.866348  2.364821
# 26                             NaN  48.854704  2.324866
# 27        9 boulevard Poissonnière  48.870940  2.346583
# 28                    27 rue Erard  48.846176  2.386590
# 29     11 bis rue de la Procession  48.839520  2.305722
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 48.867739, 'lng':...      1703      75013
# 1   [{'label': 'display', 'lat': 48.86482080982636...      1146      75002
# 2   [{'label': 'display', 'lat': 48.837677, 'lng':...      2246      75013
# 3   [{'label': 'display', 'lat': 48.853989, 'lng':...       434      75005
# 4   [{'label': 'display', 'lat': 48.85945352057837...       517      75001
# 5   [{'label': 'display', 'lat': 48.85351139737257...       450      75006
# 6   [{'label': 'display', 'lat': 48.839535, 'lng':...      3635      75015
# 7   [{'label': 'display', 'lat': 48.859215, 'lng':...       955        NaN
# 8   [{'label': 'display', 'lat': 48.84529661796112...      1063      75005
# 9   [{'label': 'display', 'lat': 48.86208673088779...      1000        NaN
# 10  [{'label': 'display', 'lat': 48.861029, 'lng':...      1263        NaN
# 11  [{'label': 'display', 'lat': 48.884677, 'lng':...      3403        NaN
# 12  [{'label': 'display', 'lat': 48.85977818722424...      4339      75020
# 13  [{'label': 'display', 'lat': 48.83822250366211...      2067      75005
# 14  [{'label': 'display', 'lat': 48.85362315372269...      1943        NaN
# 15  [{'label': 'display', 'lat': 48.85655, 'lng': ...      2216      75011
# 16  [{'label': 'display', 'lat': 48.844731, 'lng':...      2033      75015
# 17  [{'label': 'display', 'lat': 48.87126998911334...      1963        NaN
# 18  [{'label': 'display', 'lat': 48.870489011559, ...      2431        NaN
# 19  [{'label': 'display', 'lat': 48.87722033627621...      2611        NaN
# 20  [{'label': 'display', 'lat': 48.85339566986454...      2569        NaN
# 21  [{'label': 'display', 'lat': 48.876788, 'lng':...      2488      75009
# 22  [{'label': 'display', 'lat': 48.84048822780873...      2807      75015
# 23  [{'label': 'display', 'lat': 48.8487727324926,...      5748      75016
# 24  [{'label': 'display', 'lat': 48.83699738076995...      2711      75014
# 25  [{'label': 'display', 'lat': 48.86634787240057...      2005      75003
# 26  [{'label': 'display', 'lat': 48.85470430584038...      1385        NaN
# 27  [{'label': 'display', 'lat': 48.87093956210484...      1805      75009
# 28  [{'label': 'display', 'lat': 48.846176, 'lng':...      3280      75012
# 29  [{'label': 'display', 'lat': 48.83951950073242...      3267      75015
#
#     cc   city          state country  \
# 0   FR  Paris  Île-de-France  France
# 1   FR  Paris  Île-de-France  France
# 2   FR  Paris  Île-de-France  France
# 3   FR  Paris  Île-de-France  France
# 4   FR  Paris  Île-de-France  France
# 5   FR  Paris  Île-de-France  France
# 6   FR  Paris  Île-de-France  France
# 7   FR  Paris  Île-de-France  France
# 8   FR  Paris  Île-de-France  France
# 9   FR  Paris  Île-de-France  France
# 10  FR  Paris  Île-de-France  France
# 13  51043554e4b08881ebbec640
# 14  53f79936498ef939417afa78
# 15  5b5e12e160255e002c0d5d51
# 16  4ba66d6cf964a520635139e3
# 17  53f7b51b498e5ac6875be50a
# 18  543eb095498e12bc703d80a5
# 19  4e972515b634527c67a6595a
# 20  4e0328be7d8bf11e9f3c1383
# 21  4b41e2a0f964a520c7c925e3
# 22  4eef943377c82b92fa7121d1
# 23  4b8d6621f964a5206ff932e3
# 24  4d946494ca3f6ea8f502c834
# 25  4b8bffebf964a52082b732e3
# 26  4f91c6eae4b0ccf0717648df
# 27  4b5f4f04f964a52038b329e3
# 28  5559c8ae498e23395fd9c60d
# 29  4f999df4e4b03d12fb0b163e

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Paris center

# add a red circle marker to represent Paris center
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Paris Center',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_7aa35ea7be6f4ae3be5eea5bf3886cee%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7aa35ea7be6f4ae3be5eea5bf3886cee%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7aa35ea7be6f4ae3be5eea5bf3886cee%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_7aa35ea7be6f4ae3be5eea5bf3886cee%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B48.8548227%2C2.34378%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
test = dataframe_filtered.id
t = []
for i in test:
    print(i)
    venue_id = i # ID of Harry's Italian Pizza Bar
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
    #url
    result = requests.get(url).json()
    #print(result['response']['venue'].keys())
    result['response']['venue']
    try:
        print(result['response']['venue']['rating'])
        t += [result['response']['venue']['rating']]
    except:
        print('None')
        t += ['None']
# Out:
# 51430960e4b0455b2d070f45
# None
# 4c9894df07916dcb8d01ed1b
# 7.6
# 4dc445371f6ef43b89f7e46e
# None
# 4c6fb714d274b60c3d57d70d
# None
# 5371073c498e8b0d316a4db8
# None
# 5131ded7e4b04a7c69396261
# 7.3
# 523741de11d2a8888a604602
# None
# 4e59e059483b865169e59dba
# None
# 573eecb1498ebf4b4efd1b8c
# None
# 4e59fe822271886714fb58d5
# None
# 4e58fd782271886714ec7f9d
# None
# 58ce831d18fd2b1c6a40c5ec
# None
# 513130f5e4b0ed2721b6e1fa
# 8.0
# 51043554e4b08881ebbec640
# None
# 53f79936498ef939417afa78
# 6.5
# 5b5e12e160255e002c0d5d51
# None
# 4ba66d6cf964a520635139e3
# 6.7
# 53f7b51b498e5ac6875be50a
# 8.6
# 543eb095498e12bc703d80a5
# None
# 4e972515b634527c67a6595a
# None
# 4e0328be7d8bf11e9f3c1383
# None
# 4b41e2a0f964a520c7c925e3
# None
# 4eef943377c82b92fa7121d1
# None
# 4b8d6621f964a5206ff932e3
# 7.9
# 4d946494ca3f6ea8f502c834
# 6.4
# 4b8bffebf964a52082b732e3
# 7.5
# 4f91c6eae4b0ccf0717648df
# None
# 4b5f4f04f964a52038b329e3
# 5.3
# 5559c8ae498e23395fd9c60d
# None
# 4f999df4e4b03d12fb0b163e
# None

# %%
print(t) #Here we have the dataset for the Note
print(len(t))
# Out:
# ['None', 7.6, 'None', 'None', 'None', 7.3, 'None', 'None', 'None', 'None', 'None', 'None', 8.0, 'None', 6.5, 'None', 6.7, 8.6, 'None', 'None', 'None', 'None', 'None', 7.9, 6.4, 7.5, 'None', 5.3, 'None', 'None']
# 30

# %%
data2 = dataframe_filtered.loc[:, ['name', 'lat', 'lng', 'id']] #We clean the dataset to keep only relevant information
data2
# Out:
#                             name        lat       lng  \
# 0   Pizzeria Italiana Da Michele  48.867739  2.356261
# 1     O'scià Pizzeria Napoletana  48.864821  2.347524
# 2            Pizzeria d'Istanbul  48.837677  2.359962
# 3              Pizzeria Mazarine  48.853989  2.337987
# 4              Pizzeria Maccaron  48.859454  2.344401
# 5                Pizzeria Pepone  48.853511  2.337967
# 6                  Pizzeria Nino  48.839535  2.299931
# 7              Pizzeria La Gaine  48.859215  2.354996
# 8               Pizzeria Luciana  48.845297  2.342616
# 9                  Pizzeria Luka  48.862087  2.351836
# 10                Pizzeria Ghost  48.861029  2.358219
# 11                      pizzeria  48.884677  2.333735
# 12                 Mama Pizzeria  48.859778  2.402545
# 13            Pizzeria Romanella  48.838223  2.356450
# 14           Pizzeria Don Jacomo  48.853623  2.370256
# 15                Pizzeria Sette  48.856550  2.373932
# 16        Pizzeria Les Comédiens  48.844731  2.320639
# 17                Pizzeria Sette  48.871270  2.353464
# 18              Pizzeria Miramar  48.870489  2.320640
# 19        Pizzeria Saint Georges  48.877220  2.354398
# 20           Pizzeria Napoletana  48.853396  2.378799
# 21         Pizzeria Saint-Lazare  48.876788  2.337441
# 22            Pizzeria Chez Hino  48.840488  2.312244
# 23            Pizzeria d'Auteuil  48.848773  2.265839
# 24            Pizzeria Via Maria  48.836997  2.318552
# 25               Pizzeria Renato  48.866348  2.364821
# 26          Vecchia Bar Pizzeria  48.854704  2.324866
# 27              Valponi Pizzeria  48.870940  2.346583
# 28            Pizzeria Al Taglio  48.846176  2.386590
# 29               Pizzeria Verona  48.839520  2.305722
#
#                           id
# 0   51430960e4b0455b2d070f45
# 1   4c9894df07916dcb8d01ed1b
# 2   4dc445371f6ef43b89f7e46e
# 3   4c6fb714d274b60c3d57d70d
# 4   5371073c498e8b0d316a4db8
# 5   5131ded7e4b04a7c69396261
# 6   523741de11d2a8888a604602
# 7   4e59e059483b865169e59dba
# 8   573eecb1498ebf4b4efd1b8c
# 9   4e59fe822271886714fb58d5
# 10  4e58fd782271886714ec7f9d
# 11  58ce831d18fd2b1c6a40c5ec
# 12  513130f5e4b0ed2721b6e1fa
# 13  51043554e4b08881ebbec640
# 14  53f79936498ef939417afa78
# 15  5b5e12e160255e002c0d5d51
# 16  4ba66d6cf964a520635139e3
# 17  53f7b51b498e5ac6875be50a
# 18  543eb095498e12bc703d80a5
# 19  4e972515b634527c67a6595a
# 20  4e0328be7d8bf11e9f3c1383
# 21  4b41e2a0f964a520c7c925e3
# 22  4eef943377c82b92fa7121d1
# 23  4b8d6621f964a5206ff932e3
# 24  4d946494ca3f6ea8f502c834
# 25  4b8bffebf964a52082b732e3
# 26  4f91c6eae4b0ccf0717648df
# 27  4b5f4f04f964a52038b329e3
# 28  5559c8ae498e23395fd9c60d
# 29  4f999df4e4b03d12fb0b163e

# %%
t_array = np.array(t)

# %%
data2['Note'] = t_array

# %%
data2
# Out:
#                             name        lat       lng  \
# 0   Pizzeria Italiana Da Michele  48.867739  2.356261
# 1     O'scià Pizzeria Napoletana  48.864821  2.347524
# 2            Pizzeria d'Istanbul  48.837677  2.359962
# 3              Pizzeria Mazarine  48.853989  2.337987
# 4              Pizzeria Maccaron  48.859454  2.344401
# 5                Pizzeria Pepone  48.853511  2.337967
# 6                  Pizzeria Nino  48.839535  2.299931
# 7              Pizzeria La Gaine  48.859215  2.354996
# 8               Pizzeria Luciana  48.845297  2.342616
# 9                  Pizzeria Luka  48.862087  2.351836
# 10                Pizzeria Ghost  48.861029  2.358219
# 11                      pizzeria  48.884677  2.333735
# 12                 Mama Pizzeria  48.859778  2.402545
# 13            Pizzeria Romanella  48.838223  2.356450
# 14           Pizzeria Don Jacomo  48.853623  2.370256
# 15                Pizzeria Sette  48.856550  2.373932
# 16        Pizzeria Les Comédiens  48.844731  2.320639
# 17                Pizzeria Sette  48.871270  2.353464
# 18              Pizzeria Miramar  48.870489  2.320640
# 19        Pizzeria Saint Georges  48.877220  2.354398
# 20           Pizzeria Napoletana  48.853396  2.378799
# 21         Pizzeria Saint-Lazare  48.876788  2.337441
# 22            Pizzeria Chez Hino  48.840488  2.312244
# 23            Pizzeria d'Auteuil  48.848773  2.265839
# 24            Pizzeria Via Maria  48.836997  2.318552
# 25               Pizzeria Renato  48.866348  2.364821
# 26          Vecchia Bar Pizzeria  48.854704  2.324866
# 27              Valponi Pizzeria  48.870940  2.346583
# 28            Pizzeria Al Taglio  48.846176  2.386590
# 29               Pizzeria Verona  48.839520  2.305722
#
#                           id  Note
# 0   51430960e4b0455b2d070f45  None
# 1   4c9894df07916dcb8d01ed1b   7.6
# 2   4dc445371f6ef43b89f7e46e  None
# 3   4c6fb714d274b60c3d57d70d  None
# 4   5371073c498e8b0d316a4db8  None
# 5   5131ded7e4b04a7c69396261   7.3
# 6   523741de11d2a8888a604602  None
# 7   4e59e059483b865169e59dba  None
# 8   573eecb1498ebf4b4efd1b8c  None
# 9   4e59fe822271886714fb58d5  None
# 10  4e58fd782271886714ec7f9d  None
# 11  58ce831d18fd2b1c6a40c5ec  None
# 12  513130f5e4b0ed2721b6e1fa   8.0
# 13  51043554e4b08881ebbec640  None
# 14  53f79936498ef939417afa78   6.5
# 15  5b5e12e160255e002c0d5d51  None
# 16  4ba66d6cf964a520635139e3   6.7
# 17  53f7b51b498e5ac6875be50a   8.6
# 18  543eb095498e12bc703d80a5  None
# 19  4e972515b634527c67a6595a  None
# 20  4e0328be7d8bf11e9f3c1383  None
# 21  4b41e2a0f964a520c7c925e3  None
# 22  4eef943377c82b92fa7121d1  None
# 23  4b8d6621f964a5206ff932e3   7.9
# 24  4d946494ca3f6ea8f502c834   6.4
# 25  4b8bffebf964a52082b732e3   7.5
# 26  4f91c6eae4b0ccf0717648df  None
# 27  4b5f4f04f964a52038b329e3   5.3
# 28  5559c8ae498e23395fd9c60d  None
# 29  4f999df4e4b03d12fb0b163e  None
